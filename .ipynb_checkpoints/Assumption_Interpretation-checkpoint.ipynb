# %% [markdown]
# # Dari ta mag code remember to add comments kung ga what ang imong class and methods para mas understandable
# **(delete after coding and before submitting)**

# %%
#prerequites 
import numpy as np
import pandas as pd

# %%
# if wala pakay kaggle - para ni sa dataset

# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\kirst\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging in c:\users\kirst\anaconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in c:\users\kirst\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\kirst\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\kirst\anaconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kirst\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kirst\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kirst\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kirst\anaconda3\lib\site-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\kirst\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
#importing data to be used for checking
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "StudentPerformanceFactors.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "ayeshaseherr/student-performance",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\kirst\AppData\Local\Temp\ipykernel_16452\733372638.py:11: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Downloading from https://www.kaggle.com/api/v1/datasets/download/ayeshaseherr/student-performance?dataset_version_number=1&file_name=StudentPerformanceFactors.csv...
# 100%|████████████████████████████████████████| 627k/627k [00:01<00:00, 481kB/s]
# First 5 records:    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
class Data:
    """
    Initialize the data to be used in checking assumptions and 
    for getting the regression summary to make initial interpretations about 
    the model
    """
    def __init__(self, x, y, add_intercept: bool = True):
        self.x = np.ndarray(x)
        self.y = np.ndarray(y)
        self.add_intercept = add_intercept
        n = len(np.ndarray(y)) #dataset's sample size
        k = x.shape[1] #number of predictors
